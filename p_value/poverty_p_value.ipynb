# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
# Dependencies
import pandas as pd
import numpy as np
import os
import csv
from datetime import date
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import scipy.stats as stats
from scipy.stats import ttest_ind
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.offline as py

# %%
os.chdir('/Users/ruddysimonpour/Desktop/gun-violance/sources')
resource = pd.read_csv("2017 county_data_complete_REV_1.csv", parse_dates=[0], low_memory=False)

# %%
county_data = pd.DataFrame(resource)
county_data
# Out:
#                     County State  Year  Number of Incidents  Total Killed  \
# 0                     Cook    IL  2017                 3272           722
# 1                Baltimore    MD  2017                 1165           319
# 2     District of Columbia    DC  2017                 1142           100
# 3                Milwaukee    WI  2017                  849           112
# 4              Los Angeles    CA  2017                  792           406
# ...                    ...   ...   ...                  ...           ...
# 2140       Yellow Medicine    MN  2017                    1             1
# 2141                  York    NE  2017                    1             0
# 2142                  York    VA  2017                    1             1
# 2143                 Young    TX  2017                    1             2
# 2144               Ziebach    SD  2017                    1             0
#
#       Total Injured  Latitude  Longitude  Population  Median Age  \
# ...

# %%
county_data.dtypes
# Out:
# County                  object
# State                   object
# Year                     int64
# Number of Incidents      int64
# Total Killed             int64
# Total Injured            int64
# Latitude               float64
# Longitude              float64
# Population               int64
# Median Age             float64
# Household Income         int64
# Per Capita Income        int64
# Poverty Count            int64
# Poverty Rate           float64
# Unemployment Rate      float64
# dtype: object

# %% [markdown]
# ## P_value
# We decide to calculate p-values of data to check the validity of our claim about correlation between datas.
# We want to understand that is there any correlation between poverty and gun incidens ?

# %%
p_value_data = county_data[["Number of Incidents",
                            "Poverty Rate"]]
p_value_data.head()
# Out:
#    Number of Incidents  Poverty Rate
# 0                 3272     15.683222
# 1                 1165      8.877229
# 2                 1142     16.511970
# 3                  849     20.068556
# 4                  792     16.708405

# %%
poverty_m = p_value_data["Poverty Rate"].mean()
poverty_m
# Out:
# 15.81886480079677

# %%
poverty_range = p_value_data["Poverty Rate"].unique().tolist()
poverty_range
# Out:
# [15.6832217,
#  8.877228509,
#  16.51197,
#  20.0685563,
#  16.7084054,
#  15.680620300000001,
#  24.2870799,
#  24.562189899999996,
#  20.4212414,
#  16.6165472,
#  25.096183399999997,
#  17.9151281,
#  18.5300089,
#  23.4586597,
#  19.396168399999997,
#  17.191035100000004,
#  15.4433372,
#  16.2645282,
#  13.2576193,
#  16.109479699999998,
#  15.508984400000001,
#  16.7500514,
#  16.3790943,
#  17.069197199999998,
#  14.6884133,
#  14.4122236,
#  13.187694,
#  16.6314457,
#  15.688820300000001,
#  15.4904891,
#  18.6924305,
#  11.1188225,
#  12.1639063,
#  15.280879800000001,
#  21.7495653,
#  8.594911199999999,
#  15.0111995,
#  17.4989705,
#  11.306514,
#  10.032911300000002,
#  23.9673687,
#  21.6586259,
#  17.6695487,
#  18.7111552,
#  16.2272054,
#  11.545557400000002,
#  10.624855,
#  17.3096335,
#  18.8874515,
#  16.6062389,
#  10.833989500000001,
#  15.3806663,
#  25.0139973,
#  16.3146973,
#  16.5438905,
#  22.9446885,
#  14.464147500000001,
#  13.337618300000003,
# ...

# %% [markdown]
# ## Good range poverty

# %%
range_good = p_value_data.loc[p_value_data["Poverty Rate"] <= 17 ]
range_good.sort_values(by = ["Poverty Rate"], ascending = False)
# Out:
#       Number of Incidents  Poverty Rate
# 1284                    3     16.991902
# 425                    21     16.985631
# 1602                    2     16.985111
# 608                    12     16.978969
# 1363                    2     16.974995
# ...                   ...           ...
# 1085                    4      4.297748
# 639                    11      3.664853
# 507                    16      3.625600
# 1516                    2      3.012400
# 1059                    4      2.925666
#
# [1350 rows x 2 columns]

# %%
mean_good = range_good["Poverty Rate"].mean()
mean_good
# Out:
# 12.172299745117773

# %% [markdown]
# ## Medium range poverty

# %%
range_medium = p_value_data.loc[p_value_data["Poverty Rate"] > 17]
range_medium = range_medium.loc[range_medium["Poverty Rate"] <= 34 ]
range_medium.sort_values(by=["Poverty Rate"], ascending = False)
# Out:
#       Number of Incidents  Poverty Rate
# 1144                    4     33.938516
# 1488                    2     33.678080
# 1140                    4     33.613574
# 1283                    3     33.336399
# 371                    26     33.304862
# ...                   ...           ...
# 1938                    1     17.030406
# 182                    71     17.026829
# 407                    23     17.018156
# 1400                    2     17.001991
# 865                     6     17.000969
#
# [771 rows x 2 columns]

# %%
mean_medium = range_medium["Poverty Rate"].mean()
mean_medium
# Out:
# 21.499537636964963

# %% [markdown]
# ## Bad range poverty

# %%
range_bad = p_value_data.loc[p_value_data["Poverty Rate"] > 34]
range_bad = range_bad.loc[range_bad["Poverty Rate"] <= 52]
range_bad.sort_values(by = ["Poverty Rate"], ascending = False)
# Out:
#       Number of Incidents  Poverty Rate
# 1108                    4     51.367994
# 2073                    1     50.738818
# 706                     9     44.709038
# 2144                    1     42.862178
# 1922                    1     41.464597
# 1727                    1     40.674603
# 758                     8     38.910075
# 528                    15     38.534852
# 1990                    1     38.285124
# 1916                    1     37.345053
# 1537                    2     37.181018
# 1359                    2     36.710474
# 2007                    1     36.645880
# 2048                    1     36.561086
# 934                     5     36.451644
# 484                    17     35.572597
# 784                     7     35.343266
# 1280                    3     35.286285
# 1367                    2     35.236517
# 1025                    4     35.229463
# 1454                    2     34.721214
# 1606                    2     34.638915
# ...

# %%
mean_bad = range_bad["Poverty Rate"].mean()
mean_bad
# Out:
# 38.44653432083333

# %%
print(f' The average number of good range is {mean_good}.')
print(f' The average number of medium range is {mean_medium}.')
print(f' The average number of bad range is {mean_bad}.')
# Out:
#  The average number of good range is 12.172299745117773.
#  The average number of medium range is 21.499537636964963.
#  The average number of bad range is 38.44653432083333.

# %%
expected_value = (mean_good + mean_medium + mean_bad / 3)
expected_value
# Out:
# 46.48734882236051

# %%
observed = pd.Series([mean_good, mean_medium, mean_bad], index = ["Good", "Medium", "Bad"])
observed
# Out:
# Good      12.172300
# Medium    21.499538
# Bad       38.446534
# dtype: float64

# %%
df = pd.DataFrame([observed]).T
df.head()
# Out:
#                 0
# Good    12.172300
# Medium  21.499538
# Bad     38.446534

# %%
df[1] = expected_value

# %%
df.columns = ["Observed", "Expected"]
df
# Out:
#          Observed   Expected
# Good    12.172300  46.487349
# Medium  21.499538  46.487349
# Bad     38.446534  46.487349

# %%
# The degree of freedom is 3-1 = 2
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95.
critical_value = stats.chi2.ppf(q = 0.95, df = 2)
critical_value
# Out:
# 5.991464547107979

# %%
# Run the chi square test with stats.chisquare()
stats.chisquare(df['Observed'], df['Expected'])
# Out:
# Power_divergenceResult(statistic=40.15217142175901, pvalue=1.9101468541012747e-09)

# %% [markdown]
# ### There is a significance between poverty and gun violence
# We conclude from p-value which is less than 0.05 we reject the null hypothesis that there is no difference between the means and conclude that a significance correlation between unemployment rate and gun incidents which demonstrates that higher poverty rate will increase gun crimes.

# %%
l=[]
trace0= go.Scatter(
        y = county_data['Poverty Rate'],
        x = county_data["Number of Incidents"],
        mode= 'markers',
        name='Poverty (%)',
        marker= dict(size= county_data['Poverty Rate'].values,
                    line= dict(width=1),
                    color= county_data['Poverty Rate'].values,
                    opacity= 0.7,
                    colorscale='Portland',
                    showscale=True),
        text= county_data['State'].values) # The hover text goes here... 
l.append(trace0);

layout= go.Layout(
    title= 'Scatter plot of Poverty rates in 2017',
    hovermode= 'closest',
    xaxis= dict(
        ticklen= 5,
        zeroline= False,
        gridwidth= 2,
    ),
    yaxis=dict(
        title= 'Poverty Rate (%)',
        ticklen= 5,
        gridwidth= 2,
    ),
    showlegend= False,
    )
fig= go.Figure(data=l, layout=layout)
py.iplot(fig)
# Out:
# <div>
#
#
#             <div id="1f0662a5-8887-4c68-a6e6-ff13a93c6167" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f0662a5-8887-4c68-a6e6-ff13a93c6167")) {
#                     Plotly.newPlot(
#                         '1f0662a5-8887-4c68-a6e6-ff13a93c6167',
# ...
